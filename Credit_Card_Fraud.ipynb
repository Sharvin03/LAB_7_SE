# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharvin03/LAB_7_SE/blob/main/Credit_Card_Fraud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# 0 = Normal
# 1 = Fraud

# %%
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# *Undersampling*, making the normal and fradulent transaction the same amount

# %%
legit_sample = legit.sample(n=492)

# %% [markdown]
# Concat the legit_sample and fraud

# %%
new_data = pd.concat([legit_sample,fraud],axis=0)

# %%
new_data.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 209297  137496.0  2.063453  0.003071 -1.621522  0.014389  0.640003 -0.249409
# 233185  147477.0 -0.798164  0.793157 -1.071534  1.117178  0.992882 -0.375045
# 186602  127175.0 -0.679368  0.346899  1.389991  0.394815  0.559907  0.491246
# 224098  143651.0 -0.019698  0.955170 -0.628552  0.109090  0.853657 -0.236152
# 224061  143634.0 -0.556271  1.403828 -1.158957 -0.839256  0.970447 -0.049304
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 209297  0.155028 -0.175328  0.175997  ...  0.280961  0.966468 -0.041594
# 233185  1.122766  0.263233 -0.739069  ...  0.009745 -0.363269  0.098778
# 186602  0.986390 -0.075992  0.210179  ... -0.430164 -0.908408  0.063206
# 224098  1.777632 -0.241434 -0.930521  ...  0.165776  0.395539 -0.067607
# 224061  0.502721  0.408969 -0.247154  ... -0.239193 -0.825364  0.092457
#
# ...

# %%
new_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      95060.335366  0.123869 -0.043211  0.020309  0.011599  0.083528
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.013776  0.063213  0.021270  0.056990  ...  0.011839  0.031565
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.013703  0.020635  0.047397  0.004365 -0.021200 -0.014073 -0.010485
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.881809
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into features and target

# %%
X = new_data.drop(columns='Class',axis=1)
Y = new_data['Class']

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 209297  137496.0  2.063453  0.003071 -1.621522  0.014389  0.640003 -0.249409
# 233185  147477.0 -0.798164  0.793157 -1.071534  1.117178  0.992882 -0.375045
# 186602  127175.0 -0.679368  0.346899  1.389991  0.394815  0.559907  0.491246
# 224098  143651.0 -0.019698  0.955170 -0.628552  0.109090  0.853657 -0.236152
# 224061  143634.0 -0.556271  1.403828 -1.158957 -0.839256  0.970447 -0.049304
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %% [markdown]
# Splitting the data into training data and testing data

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,stratify = Y, random_state =2)

# %% [markdown]
# Model Training

# %%
model = LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %%
X_train_predict = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_predict, Y_train)
print(training_data_accuracy)
# Out:
# 0.9440914866581956

# %%
X_test_predict = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_predict, Y_test)
print(test_data_accuracy)
# Out:
# 0.934010152284264
